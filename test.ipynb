# %%
import pandas as pd

# %%
df = pd.read_excel("data2.xlsx")
df.head()
# Out:
#     id  ticker_id ticker       date  close_LogReturn  price_vs_sma50  \
# 0  1.0        1.0    ABB 2021-01-04         0.000000        0.118207
# 1  2.0        1.0    ABB 2021-01-05        -0.029977        0.118207
# 2  3.0        1.0    ABB 2021-01-06         0.046186        0.118207
# 3  4.0        1.0    ABB 2021-01-07        -0.003176        0.118207
# 4  5.0        1.0    ABB 2021-01-08         0.009132        0.118207
#
#    volatility_20  volume_ratio_20  return_1d  return_3d  ...  \
# 0       0.620643         0.522824  -0.029532   0.013118  ...
# 1       0.620643         0.522824  -0.029532   0.013118  ...
# 2       0.620643         0.522824   0.047269   0.013118  ...
# 3       0.620643         0.522824  -0.003171   0.013118  ...
# 4       0.620643         0.522824   0.009174   0.053525  ...
#
#    rsi_14_LogReturn  PCA_Trend  PCA_Oscillators  PCA_MACD  PCA_ShortReturns  \
# 0          0.000000  -1.288188        -3.311957 -0.109948         -0.000434
# ...
